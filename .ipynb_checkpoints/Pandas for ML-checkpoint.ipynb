# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pandas Series : *Like a single column of a table*
#                    **A 1-D Array Holding any type of data**
#
#                     *Series → One column*

# %%
my_series = [5,9,12,27]
my_var = pd.Series(my_series)

# %%
my_var
# Out:
# 0     5
# 1     9
# 2    12
# 3    27
# dtype: int32

# %%
## Printing Specific value
my_var[2]
# Out:
# 12

# %% [markdown]
# ## Labels using index

# %% [markdown]
# 1. What is the Index in a Series?
#
#     **The index in a Pandas Series is like a row label that helps identify and access individual values. By default, Pandas assigns an integer index starting from 0, 1, 2, ....**

# %%
my_index = ["A","B","C","D"]
my_var2 = pd.Series(my_series,my_index)
# my_var2.name = "name"

# s = pd.Series([10, 20, 30, 40], index=["a", "b", "c", "d"])

# %%
print(type(my_var2))
my_var2
# Out:
# <class 'pandas.core.series.Series'>
# A     5
# B     9
# C    12
# D    27
# dtype: int64

# %%
my_var2["D"]
# Out:
# 27

# %%
## Key valaue Dictionary

# %%
cars = {"Tesla":12,"mercedies":3,"bmw":10}
pd.Series(cars)
# Out:
# Tesla        12
# mercedies     3
# bmw          10
# dtype: int64

# %% [markdown]
# ![image.png](attachment:0e441f0d-b019-4bc1-9426-14d5554857fb.png)

# %% [markdown]
# # ------------------------ DataFrames-------------------------

# %%
from numpy.random import randn

# %%
my_Data = randn(4,3)
my_rows = ["A","B","C","D"]
my_cols = ["MOn","Tue","Wed"]

# %%
## create 'dataframe'
my_df = pd.DataFrame(my_Data,index = my_rows,columns = my_cols)# here we can directly gives the values like my_Data,my_rows,my_cols
my_df
# Out:
#         MOn       Tue       Wed
# A  0.848772 -1.055434  1.434158
# B  0.101333  0.042929 -1.287592
# C  0.888224  0.711730 -0.262615
# D  1.954148  0.873794 -0.435211

# %%
# reading Csv file

my_df2 = pd.read_csv("dog_data.csv") 
my_df2
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
## Pull out 'rows'

my_df2.loc[0]
# Out:
# Breed       COCKAPOO
# Color          BROWN
# DogName      CHARLEY
# OwnerZip       15236
# Name: 0, dtype: object

# %%
my_df2.iloc[0:4]   # returning the perticular rows

# iloc[start:step:step]
# Out:
#            Breed        Color  DogName  OwnerZip
# 0       COCKAPOO        BROWN  CHARLEY     15236
# 1   GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2  BELG MALINOIS      BRINDLE     EICH     15238
# 3          MIXED  BLACK/BROWN    ARROW     15104

# %%
# using fancy indexing

my_df2.iloc[[0,1,7,8]]
# Out:
#                Breed        Color     DogName  OwnerZip
# 0           COCKAPOO        BROWN     CHARLEY     15236
# 1       GER SHEPHERD  BLACK/BROWN      TACODA     15238
# 7      DACHSHUND MIX  WHITE/BROWN       LEROI     15101
# 8  SHETLAND SHEEPDOG  WHITE/BROWN  ZOE VITSAS     15238

# %%
## Filtering specific columns

my_df2 = df[["Breed", "OwnerZip"]] 
print(my_df2)
# Out:
#                     Breed  OwnerZip
# 0                COCKAPOO     15236
# 1            GER SHEPHERD     15238
# 2           BELG MALINOIS     15238
# 3                   MIXED     15104
# 4     AM PIT BULL TERRIER     15139
# ...                   ...       ...
# 2665         GOLDENDOODLE     15044
# 2666    YORKSHIRE TERRIER     15220
# 2667              LAB MIX     15220
# 2668         GOLDENDOODLE     15143
# 2669    SHETLAND SHEEPDOG     15136
#
# [2670 rows x 2 columns]

# %% [raw]
# # some impt function/methods
# df.head() # first 5
# df.tail() # last 5
# df.sample()  # random rows
# df.info(memory_usage = "deep")
# df.shape  # rows and columns
# df.ndim   #
# df.dtypes
# df.describe()  # 25% are the data below 'XXXX' number

# %%
# describe the specifc column
df["Breed"].describe()
# Out:
# count      2670
# unique      185
# top       MIXED
# freq        235
# Name: Breed, dtype: object

# %% [markdown]
# ![image.png](attachment:8d9bac49-1603-46de-93da-d395c6646ae8.png)

# %%
df['Color'].describe()
# Out:
# count      2665
# unique       72
# top       BLACK
# freq        371
# Name: Color, dtype: object

# %%
df['DogName'].describe()
# Out:
# count     2669
# unique    1428
# top       LUCY
# freq        35
# Name: DogName, dtype: object

# %%
df['DogName'].unique()  # .nunique()
# Out:
# array(['CHARLEY', 'TACODA', 'EICH', ..., 'ROCKY KALAKOS', 'CLARENCE',
#        'GRIFFIN'], dtype=object)

# %%
## Select Specific column Usinf Brackets

# method 1
df['DogName'] # [['DogName',"Color"]]
# Method2 : dot notation
df.Color
# Method 3 : using 'iloc' > location
df.iloc[:,0:2]  # [all rows,colmns]
# Out:
#                     Breed              Color
# 0                COCKAPOO              BROWN
# 1            GER SHEPHERD        BLACK/BROWN
# 2           BELG MALINOIS            BRINDLE
# 3                   MIXED        BLACK/BROWN
# 4     AM PIT BULL TERRIER        WHITE/BROWN
# ...                   ...                ...
# 2665         GOLDENDOODLE              BROWN
# 2666    YORKSHIRE TERRIER        BLACK/BROWN
# 2667              LAB MIX  WHITE/BLACK/BROWN
# 2668         GOLDENDOODLE              WHITE
# 2669    SHETLAND SHEEPDOG              BLACK
#
# [2670 rows x 2 columns]

# %% [markdown]
# ## count data in Dataframes

# %%
df['Color'].value_counts()  # desc
df['Color'].value_counts(ascending=True)  # Asc
# Out:
# BROWN/LIVER               1
# BROWN/FAWN                1
# BROWN/ORANGE              1
# BLACK/ORANGE/BRINDLE      1
# BLACK/BROWN/GREY          1
#                        ...
# BLACK/BROWN             183
# WHITE/BLACK             196
# WHITE                   226
# BROWN                   309
# BLACK                   371
# Name: Color, Length: 72, dtype: int64

# %%
df['DogName'].value_counts(dropna=False) 
## to check the count of 'Nah' value
# Out:
# LUCY       35
# BELLA      30
# BAILEY     29
# BUDDY      29
# DAISY      26
#            ..
# RAMBO       1
# CHOOKIE     1
# AMY         1
# DEE DEE     1
# GRIFFIN     1
# Name: DogName, Length: 1429, dtype: int64

# %%
# Get Relative Freqency  -  **Percentage**
df['Color'].value_counts(normalize=True)
# Out:
# BLACK                   0.139212
# BROWN                   0.115947
# WHITE                   0.084803
# WHITE/BLACK             0.073546
# BLACK/BROWN             0.068668
#                           ...
# BLACK/ORANGE/BRINDLE    0.000375
# BROWN/ORANGE            0.000375
# BROWN/FAWN              0.000375
# BLACK/BROWN/GREY        0.000375
# BROWN/LIVER             0.000375
# Name: Color, Length: 72, dtype: float64

# %%
# get specific values - Size

df['Color'].value_counts()['BLACK']
# Out:
# 371

# %% [markdown]
# ## ADD Columns

# %%
df =  pd.read_csv("dog_data_short.csv")

# %%
df.head()
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
# Add column from list
gender = ["Male","Female","Male","Male","Female"] 
# have to match with the np. of rows

# %%
df["Gender"] = gender
df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female

# %%
# Add default values

df["Alive/Dead"] = [True]*len(df)   #['BOB']*len(df)

# %%
df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender  Alive/Dead
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        True
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        True

# %%
# Add nan value

df['Pookies'] = np.nan

# %%
df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender  Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        True
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        True
#
#    Pookies
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# add column with '.insert' -  Allowd Position

df.insert(1,"Adopted",np.random.choice([True,False],size = len(df)))

# %%
df
# Out:
#                  Breed  Adopted        Color  DogName  OwnerZip  Gender  \
# 0             COCKAPOO    False        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD    False  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS    False      BRINDLE     EICH     15238    Male
# 3                MIXED    False  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN   OAKLEY     15139  Female
#
#    Alive/Dead  Pookies
# 0        True      NaN
# 1        True      NaN
# 2        True      NaN
# 3        True      NaN
# 4        True      NaN

# %%
df.insert(1,"Mannared",np.random.choice([True,False]*len(df)))

# %%
df
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 3                MIXED     False    False  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Gender  Alive/Dead  Pookies
# 0    Male        True      NaN
# 1  Female        True      NaN
# 2    Male        True      NaN
# 3    Male        True      NaN
# 4  Female        True      NaN

# %%
## Add column with '.assign()' - create new df
# - it just create a new df for you and don't affect the original
df2 = df.assign(have_tail = np.random.choice([True,False],size=len(df)))

# %%
df2
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 3                MIXED     False    False  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Gender  Alive/Dead  Pookies  have_tail
# 0    Male        True      NaN      False
# 1  Female        True      NaN      False
# 2    Male        True      NaN       True
# 3    Male        True      NaN      False
# 4  Female        True      NaN       True

# %% [markdown]
# ## Delete Columns & Row

# %%
df
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 3                MIXED     False    False  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Gender  Alive/Dead  Pookies
# 0    Male        True      NaN
# 1  Female        True      NaN
# 2    Male        True      NaN
# 3    Male        True      NaN
# 4  Female        True      NaN

# %%
df.drop("Gender",axis=1,inplace=True)

# %%
df
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 3                MIXED     False    False  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Alive/Dead  Pookies
# 0        True      NaN
# 1        True      NaN
# 2        True      NaN
# 3        True      NaN
# 4        True      NaN

# %%
# rows
df.drop(3) # inplace =True
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Alive/Dead  Pookies
# 0        True      NaN
# 1        True      NaN
# 2        True      NaN
# 4        True      NaN

# %%
df
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 3                MIXED     False    False  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Alive/Dead  Pookies
# 0        True      NaN
# 1        True      NaN
# 2        True      NaN
# 3        True      NaN
# 4        True      NaN

# %% [markdown]
# ## Grab Rows, Points, and Subsets form Dataframe

# %%
df
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 3                MIXED     False    False  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Alive/Dead  Pookies
# 0        True      NaN
# 1        True      NaN
# 2        True      NaN
# 3        True      NaN
# 4        True      NaN

# %%
# grab ROw 'Method -1 location'

df.iloc[0:3]
# Out:
#            Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0       COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1   GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2  BELG MALINOIS     False    False      BRINDLE     EICH     15238
#
#    Alive/Dead  Pookies
# 0        True      NaN
# 1        True      NaN
# 2        True      NaN

# %%
# Specific Points

df.iloc[1,4]
# Out:
# 'TACODA'

# %% [markdown]
# ## Coditonal Selection

# %%
data = pd.read_csv("dog_data.csv")
data
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
data[data=='BROWN']
# Out:
#      Breed  Color DogName  OwnerZip
# 0      NaN  BROWN     NaN       NaN
# 1      NaN    NaN     NaN       NaN
# 2      NaN    NaN     NaN       NaN
# 3      NaN    NaN     NaN       NaN
# 4      NaN    NaN     NaN       NaN
# ...    ...    ...     ...       ...
# 2665   NaN  BROWN     NaN       NaN
# 2666   NaN    NaN     NaN       NaN
# 2667   NaN    NaN     NaN       NaN
# 2668   NaN    NaN     NaN       NaN
# 2669   NaN    NaN     NaN       NaN
#
# [2670 rows x 4 columns]

# %%
data[data=='BROWN']['Color']
# Out:
# 0       BROWN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 2665    BROWN
# 2666      NaN
# 2667      NaN
# 2668      NaN
# 2669      NaN
# Name: Color, Length: 2670, dtype: object

# %%
data[(data['Color']=='BROWN') & (data['Breed']=='MIXED')]
# Out:
#       Breed  Color        DogName  OwnerZip
# 42    MIXED  BROWN         STELLA     15044
# 272   MIXED  BROWN           HANK     15220
# 371   MIXED  BROWN          TEDDY     15136
# 402   MIXED  BROWN      GEORGIOUS     15212
# 505   MIXED  BROWN        HERSHEY     15071
# 523   MIXED  BROWN  MINDY MAZUREK     15037
# 572   MIXED  BROWN          STEVE     15229
# 584   MIXED  BROWN           BEAR     15122
# 602   MIXED  BROWN          CHLOE     15106
# 818   MIXED  BROWN         PEANUT     15025
# 943   MIXED  BROWN        DEE DEE     15031
# 946   MIXED  BROWN           SAGE     15035
# 948   MIXED  BROWN          BELLA     15035
# 995   MIXED  BROWN         MISTER     15139
# 1006  MIXED  BROWN        VANESSA     15065
# 1042  MIXED  BROWN           JACK     15223
# 1123  MIXED  BROWN         BUDDIE     15122
# 1195  MIXED  BROWN         COOPER     15071
# 1204  MIXED  BROWN            POE     15044
# 1211  MIXED  BROWN          EPPEY     15218
# ...

# %% [markdown]
# ## Change and set the index of a value

# %%
df
# Out:
#                  Breed  Mannared  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     False    False        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     False    False  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     False    False      BRINDLE     EICH     15238
# 3                MIXED     False    False  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     False     True  WHITE/BROWN   OAKLEY     15139
#
#    Alive/Dead  Pookies
# 0        True      NaN
# 1        True      NaN
# 2        True      NaN
# 3        True      NaN
# 4        True      NaN

# %%
df.set_index("Pookies",inplace=True) # inplace True

# %%
# reset index

df.reset_index()
# Out:
#    Pookies                Breed  Mannared  Adopted        Color  OwnerZip  \
# 0      NaN             COCKAPOO     False    False        BROWN     15236
# 1      NaN         GER SHEPHERD     False    False  BLACK/BROWN     15238
# 2      NaN        BELG MALINOIS     False    False      BRINDLE     15238
# 3      NaN                MIXED     False    False  BLACK/BROWN     15104
# 4      NaN  AM PIT BULL TERRIER     False     True  WHITE/BROWN     15139
#
#    Alive/Dead
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
df.drop("Adopted",axis=1)
# Out:
#                        Breed  Mannared        Color  OwnerZip  Alive/Dead
# Pookies
# NaN                 COCKAPOO     False        BROWN     15236        True
# NaN             GER SHEPHERD     False  BLACK/BROWN     15238        True
# NaN            BELG MALINOIS     False      BRINDLE     15238        True
# NaN                    MIXED     False  BLACK/BROWN     15104        True
# NaN      AM PIT BULL TERRIER     False  WHITE/BROWN     15139        True

# %% [markdown]
# ## How to fix incomplete data

# %%
# create Dummy data

s = {
    'A':[1,2,3],
    'B':[4,np.nan,6],
    'C':[7,8,9],
    'D':[10,11,12]
}
dummy = pd.DataFrame(s)
dummy
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
# drop rows having nan data
dummy.dropna(axis=0)
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 2  3  6.0  9  12

# %%
dummy.dropna(axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %%
dummy
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
# drop with limit
dummy.dropna(thresh=2,axis=1)
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
#Replace nan with values

dummy.fillna(value="X")
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2    X  8  11
# 2  3  6.0  9  12

# %%
dummy.fillna(value=dummy['B'].mean())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  5.0  8  11
# 2  3  6.0  9  12

# %%
dummy.fillna(value=dummy['B'].max())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  6.0  8  11
# 2  3  6.0  9  12

# %%
dummy.fillna(value=dummy['B'].sum())
# Out:
#    A     B  C   D
# 0  1   4.0  7  10
# 1  2  10.0  8  11
# 2  3   6.0  9  12

# %% [markdown]
# ## Data Frame Group by

# %%
import pandas as pd
import numpy as np
# Create Data
stuff = {
    'Corporation':['Apple', 'Google', 'Meta', 'Apple', 'Google','Meta'],
    'Employees':['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150]}
# Create Dataframe
my_df = pd.DataFrame(stuff)
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# Group by corporation - to get object location in memory

company = my_df.groupby('Corporation')

# %%
company.sum()
company.mean()
company.count()
## max(),min()
## std(),var(),count()
company.describe()
# Out:
#             Salary
#              count   mean        std    min    25%    50%    75%    max
# Corporation
# Apple          2.0  165.0  49.497475  130.0  147.5  165.0  182.5  200.0
# Google         2.0  170.0  70.710678  120.0  145.0  170.0  195.0  220.0
# Meta           2.0  170.0  28.284271  150.0  160.0  170.0  180.0  190.0

# %% [markdown]
# ## Apply Function

# %%
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# Create function

def create100(x):
    return x*1000

# %%
my_df['Salary'].apply(create100)
# Out:
# 0    200000
# 1    220000
# 2    190000
# 3    130000
# 4    120000
# 5    150000
# Name: Salary, dtype: int64

# %%
print(my_df)
my_df['salery'] = my_df['Salary'].apply(create100)
#my_df['NewSalary'] = my_df['Salary'].apply(create100) # in new column
my_df
# Out:
#   Corporation Employees  Salary  salery
# 0       Apple      John     200  200000
# 1      Google     April     220  220000
# 2        Meta       Wes     190  190000
# 3       Apple      Beth     130  130000
# 4      Google    Justin     120  120000
# 5        Meta     Steph     150  150000
#   Corporation Employees  Salary  salery
# 0       Apple      John     200  200000
# 1      Google     April     220  220000
# 2        Meta       Wes     190  190000
# 3       Apple      Beth     130  130000
# 4      Google    Justin     120  120000
# 5        Meta     Steph     150  150000

# %%
def upper(x):
    return str(x).upper()

# %%
my_df['Employees'].apply(upper)
# for multiple column
my_df[['Corporation','Employees']].apply(upper)
# Out:
# 0      JOHN
# 1     APRIL
# 2       WES
# 3      BETH
# 4    JUSTIN
# 5     STEPH
# Name: Employees, dtype: object

# %%
my_df['Salary'].apply(lambda x: x*10)
# df['Employees'] = df['Employees'].astype(str).apply(lambda x: x.upper())
# Out:
# 0    2000
# 1    2200
# 2    1900
# 3    1300
# 4    1200
# 5    1500
# Name: Salary, dtype: int64

# %%
## REname column
df.rename(columns={'employees': 'Employees'}, inplace=True)

# %%
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
## sort lower to high     
my_df.sort_values('Salary')  
#.sort_values("Salery",ascending=False)
# Out:
#   Corporation Employees  Salary
# 4      Google    Justin     120
# 3       Apple      Beth     130
# 5        Meta     Steph     150
# 2        Meta       Wes     190
# 0       Apple      John     200
# 1      Google     April     220
